# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

data = pd.read_csv("train.csv")

# %%
data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
sns.plot(x = data["YearBuilt"], y = data["SalePrice"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-0e02efbaf4cc> in <module>()
# ----> 1 sns.plot(x = data["YearBuilt"], y = data["SalePrice"])
#
# AttributeError: module 'seaborn' has no attribute 'plot'

# %%
box = sns.boxplot(x = data.Neighborhood, y = data.SalePrice)
plt.savefig("boxplot.png")

# %%
box = sns.boxplot(x = data.RoofMatl, y = data.SalePrice)
plt.savefig("roof.png")
data.groupby("RoofMatl").count()
# Out:
#             Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# RoofMatl
# ClyTile      1           1         1            1        1       1      0
# CompShg   1434        1434      1434         1183     1434    1434     91
# Membran      1           1         1            1        1       1      0
# Metal        1           1         1            0        1       1      0
# Roll         1           1         1            1        1       1      0
# Tar&Grv     11          11        11            7       11      11      0
# WdShake      5           5         5            2        5       5      0
# WdShngl      6           6         6            6        6       6      0
#
#           LotShape  LandContour  Utilities    ...      PoolArea  PoolQC  \
# RoofMatl                                      ...
# ClyTile          1            1          1    ...             1       1
# CompShg       1434         1434       1434    ...          1434       5
# Membran          1            1          1    ...             1       0
# Metal            1            1          1    ...             1       0
# Roll             1            1          1    ...             1       0
# Tar&Grv         11           11         11    ...            11       1
# WdShake          5            5          5    ...             5       0
# WdShngl          6            6          6    ...             6       0
#
#           Fence  MiscFeature  MiscVal  MoSold  YrSold  SaleType  \
# RoofMatl
# ClyTile       0            0        1       1       1         1
# CompShg     276           54     1434    1434    1434      1434
# Membran       0            0        1       1       1         1
# Metal         0            0        1       1       1         1
# Roll          0            0        1       1       1         1
# Tar&Grv       2            0       11      11      11        11
# WdShake       0            0        5       5       5         5
# WdShngl       3            0        6       6       6         6
#
#           SaleCondition  SalePrice
# RoofMatl
# ClyTile               1          1
# CompShg            1434       1434
# Membran               1          1
# Metal                 1          1
# Roll                  1          1
# Tar&Grv              11         11
# WdShake               5          5
# WdShngl               6          6
#
# [8 rows x 80 columns]

# %%
data.plot(x = "OverallQual", y = "YearRemodAdd", kind = "scatter")

# %%
data.plot(x = "TotRmsAbvGrd", y = "SalePrice", kind = "scatter")

# %%
data.plot(x = "TotalBsmtSF", y = "SalePrice", kind = "scatter")

# %%
data.plot(x = "1stFlrSF", y = "SalePrice", kind = "scatter")

# %%
data.plot(x = "GarageArea", y = "SalePrice", kind = "scatter")

# %%
scatter = data.plot(x = "OverallQual", y = "SalePrice", kind = "scatter")
plt.savefig("scatter.png")

# %%
data.boxplot(column = "SalePrice", by = "ExterQual")

# %%
data.boxplot(column = "SalePrice", by = "KitchenQual")

# %%
data.boxplot(column = "SalePrice", by = "BsmtQual")

# %%
data.boxplot(column = "SalePrice", by = "Neighborhood")

# %%
data.boxplot(column = "SalePrice", by = "MiscFeature")
